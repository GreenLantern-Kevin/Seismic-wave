# %%
import obspy

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from obspy.core import read

# %%
st1 = read("GS.ZHQ.00.BHE.SAC")
st2 = read("GS.ZHQ.00.BHN.SAC")
st3 = read("GS.ZHQ.00.BHZ.SAC")

# %%
print(st1)
print(st2)
print(st3)
# Out:
# 1 Trace(s) in Stream:
# GS.ZHQ.00.BHE | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:15.540000Z | 100.0 Hz, 260455 samples
# 1 Trace(s) in Stream:
# GS.ZHQ.00.BHN | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:19.560000Z | 100.0 Hz, 260857 samples
# 1 Trace(s) in Stream:
# GS.ZHQ.00.BHZ | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:19.600000Z | 100.0 Hz, 260861 samples

# %%
len(st1)
len(st2)
len(st3)
# Out:
# 1

# %%
tr1 = st1[0]
tr2 = st2[0]
tr3 = st3[0]

# %%
print(tr1)
print(tr2)
print(tr3)
# Out:
# GS.ZHQ.00.BHE | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:15.540000Z | 100.0 Hz, 260455 samples
# GS.ZHQ.00.BHN | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:19.560000Z | 100.0 Hz, 260857 samples
# GS.ZHQ.00.BHZ | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:19.600000Z | 100.0 Hz, 260861 samples

# %%
print(tr1.stats)
print(tr2.stats)
print(tr3.stats)
# Out:
#          network: GS
#          station: ZHQ
#         location: 00
#          channel: BHE
#        starttime: 2010-08-07T14:55:51.000000Z
#          endtime: 2010-08-07T15:39:15.540000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 260455
#            calib: 1.0
#          _format: SAC
#              sac: AttribDict({'delta': 0.0099999998, 'depmin': -138540.0, 'depmax': 60959.0, 'scale': 1.0, 'b': 0.0, 'e': 2604.54, 'depmen': -95.283356, 'nzyear': 2010, 'nzjday': 219, 'nzhour': 14, 'nzmin': 55, 'nzsec': 51, 'nzmsec': 0, 'nvhdr': 6, 'npts': 260455, 'iftype': 1, 'iztype': 9, 'leven': 1, 'lpspol': 1, 'lovrok': 1, 'lcalda': 0, 'kstnm': 'ZHQ', 'khole': '00', 'kcmpnm': 'BHE', 'knetwk': 'GS'})
#          network: GS
#          station: ZHQ
#         location: 00
#          channel: BHN
#        starttime: 2010-08-07T14:55:51.000000Z
#          endtime: 2010-08-07T15:39:19.560000Z
#    sampling_rate: 100.0
#            delta: 0.01
#             npts: 260857
# ...

# %%
tr1.stats.station
tr2.stats.station
tr3.stats.station
# Out:
# 'ZHQ'

# %%
tr1.data
tr2.data
tr3.data
# Out:
# array([-129111., -129116., -129093., ...,    5413.,    2700.,   30204.], dtype=float32)

# %%
tr1.data[0:100]
tr2.data[0:100]
tr3.data[0:100]
# Out:
# array([-129111., -129116., -129093., -129102., -129129., -129111.,
#        -129109., -129140., -129134., -129123., -129116., -129106.,
#        -129124., -129127., -129120., -129112., -129125., -129130.,
#        -129108., -129112., -129131., -129139., -129131., -129151.,
#        -129158., -129155., -129173., -129152., -129133., -129148.,
#        -129163., -129148., -129150., -129169., -129164., -129168.,
#        -129162., -129163., -129172., -129168., -129173., -129172.,
#        -129176., -129170., -129161., -129174., -129176., -129173.,
#        -129152., -129164., -129201., -129188., -129179., -129173.,
#        -129178., -129192., -129197., -129208., -129189., -129169.,
#        -129174., -129192., -129197., -129185., -129171., -129172.,
#        -129168., -129169., -129176., -129154., -129181., -129193.,
#        -129171., -129185., -129180., -129188., -129188., -129192.,
#        -129208., -129197., -129199., -129183., -129199., -129232.,
# ...

# %%
len(tr1)
len(tr2)
len(tr3)
# Out:
# 260861

# %%
st1.plot()
st2.plot()
st3.plot()

# %%
singlechannel =read("GS.ZHQ.00.BHE.SAC")

# %%
singlechanne2 =read("GS.ZHQ.00.BHN.SAC")

# %%
singlechanne3 =read("GS.ZHQ.00.BHZ.SAC")

# %%
print(singlechannel)
print(singlechanne2)
print(singlechanne3)
# Out:
# 1 Trace(s) in Stream:
# GS.ZHQ.00.BHE | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:15.540000Z | 100.0 Hz, 260455 samples
# 1 Trace(s) in Stream:
# GS.ZHQ.00.BHN | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:19.560000Z | 100.0 Hz, 260857 samples
# 1 Trace(s) in Stream:
# GS.ZHQ.00.BHZ | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:19.600000Z | 100.0 Hz, 260861 samples

# %%
singlechannel.plot()
singlechanne2.plot()
singlechanne3.plot()

# %%
dt1 =singlechannel[0].stats.starttime
dt2 =singlechanne2[0].stats.starttime
dt3 =singlechanne3[0].stats.starttime

# %%
singlechannel.plot(color='red',number_of_ticks=7,tick_rotation=5,tick_format='%I:%M %p',starttime=dt1+2000,endtime=dt1+2604)
singlechanne2.plot(color='blue',number_of_ticks=7,tick_rotation=5,tick_format='%I:%M %p',starttime=dt2+2000,endtime=dt2+2604)
singlechanne3.plot(color='green',number_of_ticks=7,tick_rotation=5,tick_format='%I:%M %p',starttime=dt3+2000,endtime=dt3+2604)

# %%
singlechannel.plot(color='red',number_of_ticks=7,tick_rotation=5,tick_format='%I:%M %p',starttime=dt1+2000,endtime=dt1+2604,outfile='singlechannel.png')
singlechanne2.plot(color='blue',number_of_ticks=7,tick_rotation=5,tick_format='%I:%M %p',starttime=dt2+2000,endtime=dt2+2604,outfile='singlechanne2.png')
singlechanne3.plot(color='green',number_of_ticks=7,tick_rotation=5,tick_format='%I:%M %p',starttime=dt3+2000,endtime=dt3+2604,outfile='singlechanne3.png')

# %%
singlechannel.plot(type='dayplot',interval=15,right_vertical_labels=False,one_tick_per_line=True,color=['k','r','b','g'])
singlechanne2.plot(type='dayplot',interval=15,right_vertical_labels=False,one_tick_per_line=True,color=['k','r','b','g'])
singlechanne3.plot(type='dayplot',interval=15,right_vertical_labels=False,one_tick_per_line=True,color=['k','r','b','g'])

# %% [markdown]
# # 滤波处理

# %%
tr1_filt = tr1.copy()

# %%
tr1_filt.filter('lowpass',freq=1, corners=2, zerophase=True)
# Out:
# GS.ZHQ.00.BHE | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:15.540000Z | 100.0 Hz, 260455 samples

# %%
t = np.arange(0, tr1.stats.npts / tr1.stats.sampling_rate, tr1.stats.delta)

# %%
plt.subplot(211) 
plt.plot(t,tr1.data, 'k') 
plt.ylabel('Raw Data') 
plt.subplot(212) 
plt.plot(t,tr1_filt.data, 'k') 
plt.ylabel('Lowpassed Data') 
plt.xlabel('Time [s]')
plt.suptitle(tr1.stats.starttime) 
plt.show()

# %% [markdown]
# # 下采样处理

# %%
tr1_new = tr1.copy()

# %%
tr1_new.decimate(factor=4, strict_length=False)
# Out:
# GS.ZHQ.00.BHE | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:15.520000Z | 25.0 Hz, 65114 samples

# %%
tr1_filt = tr1.copy()

# %%
tr1_filt.filter('lowpass', freq=0.4 * tr1.stats.sampling_rate / 4.0)
# Out:
# GS.ZHQ.00.BHE | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:15.540000Z | 100.0 Hz, 260455 samples

# %%
t1= np.arange(0, tr1.stats.npts / tr1.stats.sampling_rate, tr1.stats.delta)

# %%
t1_new = np.arange(0, tr1_new.stats.npts / tr1_new.stats.sampling_rate,tr1_new.stats.delta)

# %%
plt.plot(t1, tr1.data, 'k', label='Raw', alpha=0.3) 
plt.plot(t1, tr1_filt.data, 'b', label='Lowpassed', alpha=0.7) 
plt.plot(t1_new, tr1_new.data, 'r', label='Lowpassed/Downsampled', alpha=0.7) 
plt.xlabel('Time [s]') 
plt.xlim(2000, 2600) 
#plt.ylim(-200, 100)
plt.suptitle(tr1.stats.starttime) 
plt.legend() 
plt.show()

# %% [markdown]
# # FK分析

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.dates as mdates

# %%
from obspy.core.util import AttribDict

# %%
from obspy.imaging.cm import obspy_sequential

# %%
from obspy.signal.invsim import corn_freq_2_paz

# %%
from obspy.signal.array_analysis import array_processing

# %%
st1[0].stats.paz = AttribDict({ 'poles': [(-0.03736 - 0.03617j), (-0.03736 + 0.03617j)], 'zeros': [0j, 0j], 'sensitivity': 205479446.68601453, 'gain': 1.0})

# %%
st1[0].stats.coordinates = AttribDict({ 'latitude': 48.108589, 'elevation': 0.450000, 'longitude': 11.582967})

# %%
paz1hz = corn_freq_2_paz(1.0,damp=0.707) 
st1.simulate(paz_remove='self', paz_simulate=paz1hz)
# Out:
# 1 Trace(s) in Stream:
# GS.ZHQ.00.BHE | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:15.540000Z | 100.0 Hz, 260455 samples

# %%
stime = obspy.UTCDateTime("20100807145551") 
etime = obspy.UTCDateTime("20100807153000")

# %%
kwargs = dict(
    # slowness grid: X min, X max, Y min, Y max, Slow Step 
    sll_x=-3.0, slm_x=3.0, sll_y=-3.0, slm_y=3.0, sl_s=0.03, 
    # sliding window properties 
    win_len=1.0, win_frac=0.05, 
    # frequency properties 
    frqlow=1.0, frqhigh=8.0, prewhiten=0, 
    # restrict output 
    semb_thres=-1e9, vel_thres=-1e9, timestamp='mlabday', stime=stime, etime=etime )

# %%
out = array_processing(st1, **kwargs)

# %%
labels = ['rel.power', 'abs.power', 'baz', 'slow'] 
xlocator = mdates.AutoDateLocator() 
fig = plt.figure() 
for i, lab in enumerate(labels): 
    ax = fig.add_subplot(4, 1, i + 1) 
    ax.scatter(out[:, 0], out[:, i + 1], c=out[:, 1],alpha=0.6, edgecolors='none', cmap=obspy_sequential) 
    ax.set_ylabel(lab) 
    #ax.set_xlim(out[0, 0], out[-1, 0]) 
    #ax.set_ylim(out[:, i + 1].min(), out[:, i + 1].max()) 
    ax.xaxis.set_major_locator(xlocator) 
    ax.xaxis.set_major_formatter(mdates.AutoDateFormatter(xlocator)) 
    
    fig.suptitle('Zhouqu %s' % ( stime.strftime('%Y-%m-%d'), )) 
    fig.autofmt_xdate() 
    fig.subplots_adjust(left=0.15, top=0.95, right=0.95, bottom=0.2, hspace=0) 
    plt.show()

# %%
 dt =singlechannel[0].stats.starttime

# %%
threechannels.plot(size=(800, 600))

# %%
singlechannel =read("GS.ZHQ.00.BHN.SAC")

# %%
print(singlechannel)
# Out:
# 1 Trace(s) in Stream:
# GS.ZHQ.00.BHN | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:19.560000Z | 100.0 Hz, 260857 samples

# %%
threechannels =read("GS.ZHQ.00.BHN.SAC")
threechannels +=read("GS.ZHQ.00.BHN.SAC")
threechannels +=read("GS.ZHQ.00.BHN.SAC")
print(threechannels)
# Out:
# 3 Trace(s) in Stream:
# GS.ZHQ.00.BHN | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:19.560000Z | 100.0 Hz, 260857 samples
# GS.ZHQ.00.BHN | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:19.560000Z | 100.0 Hz, 260857 samples
# GS.ZHQ.00.BHN | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:19.560000Z | 100.0 Hz, 260857 samples

# %%
singlechannel.plot()

# %%
threechannels.plot(size=(800, 600))

# %%
singlechannel =read("GS.ZHQ.00.BHZ.SAC")

# %%
print(singlechannel)
# Out:
# 1 Trace(s) in Stream:
# GS.ZHQ.00.BHZ | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:19.600000Z | 100.0 Hz, 260861 samples

# %%
threechannels =read("GS.ZHQ.00.BHZ.SAC")
threechannels +=read("GS.ZHQ.00.BHZ.SAC")
threechannels +=read("GS.ZHQ.00.BHZ.SAC")
print(threechannels)
# Out:
# 3 Trace(s) in Stream:
# GS.ZHQ.00.BHZ | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:19.600000Z | 100.0 Hz, 260861 samples
# GS.ZHQ.00.BHZ | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:19.600000Z | 100.0 Hz, 260861 samples
# GS.ZHQ.00.BHZ | 2010-08-07T14:55:51.000000Z - 2010-08-07T15:39:19.600000Z | 100.0 Hz, 260861 samples

# %%
singlechannel.plot()

# %%
threechannels.plot(size=(800, 600))

# %%
st = read("GS.ZHQ.00.BHE.20100807000002.mseed")

for tr in st:
    fname = "%s.%s.%s.%s.SAC" % (tr.stats.network, tr.stats.station, tr.stats.location, tr.stats.channel)
    tr.write(fname, format="SAC")

st = read("GS.ZHQ.00.BHN.20100807000002.mseed")

for tr in st:
    fname = "%s.%s.%s.%s.SAC" % (tr.stats.network, tr.stats.station, tr.stats.location, tr.stats.channel)
    tr.write(fname, format="SAC")

st = read("GS.ZHQ.00.BHZ.20100807000001.mseed")

for tr in st:
    fname = "%s.%s.%s.%s.SAC" % (tr.stats.network, tr.stats.station, tr.stats.location, tr.stats.channel)
    tr.write(fname, format="SAC")
